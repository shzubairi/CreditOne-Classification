# %%
import numpy as np
import pandas as pd
import scipy
from math import sqrt
import matplotlib.pyplot as plt

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score as cks
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import train_test_split

# %%
rawData = pd.read_csv('new_default of credit card clients.csv', header=0)
print(rawData)
# Out:
#        Unnamed: 0  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 0               0      20000    2          2         1   24      2      2
# 1               1     120000    2          2         2   26     -1      2
# 2               2      90000    2          2         2   34      0      0
# 3               3      50000    2          2         1   37      0      0
# 4               4      50000    1          2         1   57     -1      0
# ...           ...        ...  ...        ...       ...  ...    ...    ...
# 29995       29995     220000    1          3         1   39      0      0
# 29996       29996     150000    1          3         2   43     -1     -1
# 29997       29997      30000    1          2         2   37      4      3
# 29998       29998      80000    1          3         1   41      1     -1
# 29999       29999      50000    1          2         1   46      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
rawData.describe()
# Out:
#          Unnamed: 0       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   14999.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        0.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7499.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    14999.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22499.250000   240000.000000      2.000000      2.000000      2.000000
# max    29999.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
features = rawData.iloc[:,0:24]
print('Summary of feature sample')
features.head()
# Out:
# Summary of feature sample
#    Unnamed: 0  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0           0      20000    2          2         1   24      2      2     -1
# 1           1     120000    2          2         2   26     -1      2      0
# 2           2      90000    2          2         2   34      0      0      0
# 3           3      50000    2          2         1   37      0      0      0
# 4           4      50000    1          2         1   57     -1      0     -1
#
#    PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1  ...        689          0          0          0         0       689
# 1      0  ...       2682       3272       3455       3261         0      1000
# 2      0  ...      13559      14331      14948      15549      1518      1500
# 3      0  ...      49291      28314      28959      29547      2000      2019
# 4      0  ...      35835      20940      19146      19131      2000     36681
#
# ...

# %%
features.tail()
# Out:
#        Unnamed: 0  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 29995       29995     220000    1          3         1   39      0      0
# 29996       29996     150000    1          3         2   43     -1     -1
# 29997       29997      30000    1          2         2   37      4      3
# 29998       29998      80000    1          3         1   41      1     -1
# 29999       29999      50000    1          2         1   46      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# 29995      0      0  ...     208365      88004      31237      15980
# 29996     -1     -1  ...       3502       8979       5190          0
# 29997      2     -1  ...       2758      20878      20582      19357
# 29998      0      0  ...      76304      52774      11855      48944
# 29999      0      0  ...      49764      36535      32428      15313
#
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
depVar = rawData['default payment next month']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, depVar, test_size=0.30, random_state=13)
X_train
# Out:
#        Unnamed: 0  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 14623       14623      30000    2          2         2   23      1      2
# 26475       26475     120000    2          2         1   52      1      2
# 13595       13595      50000    2          2         1   39      0      0
# 14958       14958     360000    1          2         2   48      0      0
# 24529       24529     210000    1          1         2   41     -1     -1
# ...           ...        ...  ...        ...       ...  ...    ...    ...
# 27366       27366     390000    1          1         2   28      0      0
# 24080       24080     160000    1          2         2   28      0      0
# 74             74     340000    1          1         2   32     -1     -1
# 14512       14512     360000    1          2         2   30     -2     -1
# 338           338      50000    2          2         1   31      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ...

# %%
y_train
# Out:
# 14623    1
# 26475    1
# 13595    0
# 14958    0
# 24529    1
#         ..
# 27366    0
# 24080    0
# 74       0
# 14512    0
# 338      1
# Name: default payment next month, Length: 21000, dtype: int64

# %%
X_test
# Out:
#        Unnamed: 0  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 3195         3195      20000    1          3         2   39      0      0
# 15960       15960     300000    2          1         2   30      0      0
# 17713       17713     120000    2          1         2   30      0      0
# 17897       17897     110000    1          1         2   27      0      0
# 23049       23049     200000    2          1         1   41      1     -1
# ...           ...        ...  ...        ...       ...  ...    ...    ...
# 26430       26430     400000    2          3         1   47     -2     -2
# 792           792     410000    1          1         2   32     -1     -1
# 12192       12192      80000    2          2         1   37      1      2
# 20698       20698      80000    1          3         2   44      0      0
# 10462       10462     330000    2          1         1   36      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ...

# %%
y_test
# Out:
# 3195     0
# 15960    0
# 17713    0
# 17897    0
# 23049    1
#         ..
# 26430    0
# 792      0
# 12192    0
# 20698    1
# 10462    0
# Name: default payment next month, Length: 9000, dtype: int64

# %%
modelSVC = SVC(kernel='rbf')
modelRF = RandomForestClassifier(n_estimators=100)
modelNB = GaussianNB()

# %%
features = rawData.iloc[:,0:24]
print('Summary of feature sample')
features.head()
# Out:
# Summary of feature sample
#    Unnamed: 0  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0           0      20000    2          2         1   24      2      2     -1
# 1           1     120000    2          2         2   26     -1      2      0
# 2           2      90000    2          2         2   34      0      0      0
# 3           3      50000    2          2         1   37      0      0      0
# 4           4      50000    1          2         1   57     -1      0     -1
#
#    PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1  ...        689          0          0          0         0       689
# 1      0  ...       2682       3272       3455       3261         0      1000
# 2      0  ...      13559      14331      14948      15549      1518      1500
# 3      0  ...      49291      28314      28959      29547      2000      2019
# 4      0  ...      35835      20940      19146      19131      2000     36681
#
# ...

# %%
print(depVar)
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default payment next month, Length: 30000, dtype: int64

# %%
modelRF.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
modelSVC.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
modelNB.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
modelRF.score(X_train, y_train)
# Out:
# 0.9999047619047619

# %%
modelSVC.score(X_train, y_train)
# Out:
# 0.7790952380952381

# %%
modelNB.score(X_train, y_train)
# Out:
# 0.3963809523809524

# %%
modelRF.fit(X_train, y_train)
print(cross_val_score(modelRF, X_train, y_train))
modelRF.score(X_train, y_train)
# Out:
# [0.81333333 0.81785714 0.81452381 0.82166667 0.82071429]
# 1.0

# %%
modelSVC.fit(X_train, y_train)
print(cross_val_score(modelSVC, X_train, y_train))
modelSVC.score(X_train, y_train)
# Out:
# [0.77880952 0.77880952 0.77904762 0.77904762 0.77904762]
# 0.7790952380952381

# %%
modelNB.fit(X_train, y_train)
print(cross_val_score(modelNB, X_train, y_train))
modelNB.score(X_train, y_train)
# Out:
# [0.40904762 0.38666667 0.39071429 0.38666667 0.40761905]
# 0.3963809523809524

# %%
predictions = modelRF.predict(X_test)
predAccuracy = accuracy_score(y_test, predictions)
predKappa = cks(y_test, predictions)
print('Accuracy: %.3f' % predAccuracy)
print('Kappa: %.3f' % predKappa)
# Out:
# Accuracy: 0.817
# Kappa: 0.367
